# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import chess
import chess.pgn
from stockfish import Stockfish

print("All imports worked from VS Code notebook!")
# Out:
# All imports worked from VS Code notebook!
